# %% [markdown]
# ## Построение социальных графов. Меры центральности
# ## Ирина Соколова

# %% [markdown]
# **Задание 1 (10 баллов)**
#
# Прочитайте данные из ```emails.csv```. В колонке ```message``` содержится информация о письме. Вам нужно сформировать несколько таблиц по данным для комфортной работы.
#
# Во-первых, у Вас имеется информация от том от когдо было отправленно письмо и кому:
#
# * ```From``` - email отправителя
# * ```X-From``` - имя отправитела
# * ```To``` - email получателя
# * ```X-To``` - имя получателя
#
# Каждому индивидууму нужно присвоить свой уникальный ```id``` и сформировать таблицу, где по нему можно получить ```email``` и имя.
#
# Также Вам нужно сформировать таблицу, в которой по каждому письму будет содержаться:
#
# * Дата
# * ```id``` отправителя
# * ```id``` получателей (обратитие внимание на то, что одно письмо может получать несколько человек)
# * Текст

# %%
import pandas as pd
import re
from tqdm import tqdm_notebook as tqdm
import numpy as np

# %%
df = pd.read_csv("emails.csv")

# %%
emails = df["message"].values

# %%
EMAIL_INFO = re.compile(".+?X-FileName: .*?\n", re.DOTALL)
SENDER_EMAIL = re.compile('(?<=\nFrom: ).+?(?=\n)')
RECIPIENT_EMAILS = re.compile('(?<=\nTo: ).+?(?=\nSubject:)|(?<=\nCc: ).+?(?=\nMime:)|(?<=\nBcc: ).+?(?=\nX-From:)')
SENDER_NAME = re.compile('(?<=\nX-From: ).+?(?=\nX-To:)')
RECIPIENT_NAMES = re.compile('(?<=\nX-To: ).+?(?=\nX-cc:)|(?<=\nX-cc: ).+?(?=\nX-bcc:)|(?<=\nX-bcc: ).+?(?=\nX-Folder:)')
DATE = re.compile('(?<=\nDate: ).+?(?=\n)')

# %%
def extract_sender_recipient(email):
    info = re.findall(EMAIL_INFO, email)
    
 
    sender_address = re.findall(SENDER_EMAIL, info[0])
    if sender_address:
        from_address = sender_address[0].strip()
    else:
        from_address = "unknown"
    
    
    recipient_address = re.findall(RECIPIENT_EMAILS, info[0])
    rec_addresses_lst = []
    for a in recipient_address:
        if "," in a:
            lst = a.split(",")
            rec_addresses_lst.extend(lst)
        else:
            rec_addresses_lst.append(a)
    to_addresses = [addr.strip() for addr in rec_addresses_lst]
    
    

    sender_name = re.findall(SENDER_NAME, info[0])
    from_name = remove_symbols(sender_name[0])

    
    
    
    recipient_name = re.findall(RECIPIENT_NAMES, info[0])
    rec_names_lst = []
    for n in recipient_name:
        if "," in n:
            lst = n.split(",")
            rec_names_lst.extend(lst)
        else:
            rec_names_lst.append(n)
    to_names = [remove_symbols(name) for name in rec_names_lst]
    
    return (from_address, to_addresses, from_name, to_names)

# %%
def name_address_mappings(email):
    people = extract_sender_recipient(email)
    sender_dict = {people[2]: people[0]}
    recipient_dict = {people[3][i]: people[1][i] for i in range(len(people[3])) if len(people[3]) == len(people[1])}
    big_dict = {**recipient_dict, **sender_dict}
    return big_dict

# %%
def remove_symbols(s):
    s = re.sub("<.*?>", "", s)
    s = s.strip()
    s = re.sub('"', '', s)
    return s

# %%
dicts = []

for email in tqdm(emails[:1000]):
    d = name_address_mappings(email)
    dicts.append(d)
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
all_people_dict = {}
for d in dicts:
    all_people_dict.update(d)

# %%
names = []
addresses = []
for key in all_people_dict:
    names.append(key)
    addresses.append(all_people_dict[key])

# %%
people_df = pd.DataFrame({"id": range(len(all_people_dict)),
                          "name": names,
                          "address": addresses})

# %%
people_df
# Out:
#       id                                           name  \
# 0      0                                     Tim Belden
# 1      1                                Phillip K Allen
# 2      2                                John J Lavorato
# 3      3                               Leah Van Arsdall
# 4      4                                  Randall L Gay
# 5      5                                     Greg Piper
# 6      6                      david.l.johnson@enron.com
# 7      7                                    John Shafer
# 8      8                                 Joyce Teixeira
# 9      9                                     Mark Scott
# 10    10                                zimam@enron.com
# 11    11                     stagecoachmama@hotmail.com
# 12    12                                    Keith Holst
# 13    13                               David W Delainey
# 14    14                                   Paula Harris
# 15    15                                     Ina Rangel
# 16    16                                Tim Heizenrader
# 17    17                           pallen70@hotmail.com
# 18    18                             bs_stone@yahoo.com
# 19    19                               Steve Touchstone
# 20    20                              BS Stone  @ ENRON
# 21    21                                   Lkuch@mh.com
# 22    22                                Jeffrey T Hodge
# 23    23                               kholst@enron.com
# 24    24                                       rlehmann
# 25    25                                Cindy Cicchetti
# 26    26                            jsmith@austintx.com
# 27    27                           Christopher F Calger
# 28    28                     muller@thedoghousemail.com
# 29    29                                  Kathy M Moore
# ..   ...                                            ...
# 236  236                                           list
# 237  237                               bobregon@bga.com
# 238  238            subscriptions@intelligencepress.com
# 239  239                                  CALXA@aol.com
# 240  240                            strawbale@crest.org
# 241  241    rob_tom@freenet.carleton.ca (Robert W. Tom)
# 242  242                          absteen@dakotacom.net
# 243  243  moore.john.e@worldnet.att.net (John E. Moore)
# 244  244             ENERGYINSIGHT@SPECTOR.FTENERGY.COM
# 245  245                          Energy Insight Editor
# 246  246                         billc@greenbuilder.com
# 247  247                                 Dean Sacerdote
# 248  248                                           Matt
# 249  249                                       The HCFR
# 250  250                      owner-strawbale@crest.org
# 251  251                                       Kim Ward
# 252  252                             GrenSheltr@aol.com
# 253  253                           pallen@ect.enron.com
# 254  254                                Yahoo! Delivers
# 255  255              EINSIGHTHTML@SPECTOR.FTENERGY.COM
# 256  256           Performance Evaluation Process (PEP)
# 257  257                           pallen@ECT.ENRON.COM
# 258  258                                    NYTimes.com
# 259  259                              Alyse Herasimchuk
# 260  260                                  Lisa Jacobson
# 261  261                                Richard Shapiro
# 262  262                                    Greg Thorse
# 263  263                                 Tiffany Miller
# 264  264                                  Philip Polsky
# 265  265                                     Mark Whitt
#
#                                  address
# 0                   tim.belden@enron.com
# 1                phillip.allen@enron.com
# 2                john.lavorato@enron.com
# 3                 leah.arsdall@enron.com
# 4                  randall.gay@enron.com
# 5                   greg.piper@enron.com
# 6              david.l.johnson@enron.com
# 7                  john.shafer@enron.com
# 8               joyce.teixeira@enron.com
# 9                   mark.scott@enron.com
# 10                       zimam@enron.com
# 11            stagecoachmama@hotmail.com
# 12                 keith.holst@enron.com
# 13              david.delainey@enron.com
# 14                paula.harris@enron.com
# 15                  ina.rangel@enron.com
# 16             tim.heizenrader@enron.com
# 17                  pallen70@hotmail.com
# 18                    bs_stone@yahoo.com
# 19             stouchstone@natsource.com
# 20                    bs_stone@yahoo.com
# 21                          lkuch@mh.com
# 22               jeffrey.hodge@enron.com
# 23                      kholst@enron.com
# 24                    rlehmann@yahoo.com
# 25             cindy.cicchetti@enron.com
# 26                   jsmith@austintx.com
# 27          christopher.calger@enron.com
# 28            muller@thedoghousemail.com
# 29                 kathy.moore@enron.com
# ..                                   ...
# 236                  strawbale@crest.org
# 237                     bobregon@bga.com
# 238  subscriptions@intelligencepress.com
# 239                        calxa@aol.com
# 240                  strawbale@crest.org
# 241          rob_tom@freenet.carleton.ca
# 242                absteen@dakotacom.net
# 243        moore.john.e@worldnet.att.net
# 244   energyinsight@spector.ftenergy.com
# 245               ei_editor@ftenergy.com
# 246               billc@greenbuilder.com
# 247             dean.sacerdote@enron.com
# 248                  matt@fastpacket.net
# 249                     jfreeman@ssm.net
# 250            owner-strawbale@crest.org
# 251                   kim.ward@enron.com
# 252                   grensheltr@aol.com
# 253                 pallen@ect.enron.com
# 254         yahoo-delivers@yahoo-inc.com
# 255    einsighthtml@spector.ftenergy.com
# 256                   perfmgmt@enron.com
# 257                 pallen@ect.enron.com
# 258           announce@inbox.nytimes.com
# 259          alyse.herasimchuk@enron.com
# 260              lisa.jacobson@enron.com
# 261            richard.shapiro@enron.com
# 262                    gthorse@keyad.com
# 263             tiffany.miller@enron.com
# 264              philip.polsky@enron.com
# 265                 mark.whitt@enron.com
#
# [266 rows x 3 columns]

# %%
def extract_date(email):
    info = re.findall(EMAIL_INFO, email)
    date = re.findall(DATE, info[0])
    d = re.findall('(?<=\w\w\w, )\d{1,2} \w\w\w \d\d\d\d', date[0])
    return d[0]

# %%
def extract_text(email):
    m = re.match(".+?X-FileName: .*?\n(.*)", email, re.DOTALL)
    return m.group(1)

# %%
dates = []
texts = []
senders = []
recipients = []
for email in tqdm(emails[:1000]):
    try:
        date = extract_date(email)
        dates.append(date)
        text = extract_text(email)
        texts.append(text)
        sender_name, recipient_names = extract_sender_recipient(email)[2], extract_sender_recipient(email)[3]
        senders.append(sender_name)
        recipients.append(recipient_names)
    except KeyError:
        pass
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/Users/ika/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/ika/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/Users/ika/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration

# %%
ids = people_df["id"].tolist()
name_id_map = dict(zip(names, ids))

# %%
sender_ids = []
for sender in senders:
    s_id = name_id_map[sender]
    sender_ids.append(s_id)

recipient_ids = []
for recipient in recipients:
    r_list = []
    for r in recipient:
        try:
            r_id = name_id_map[r]
            r_list.append(r_id)
        except KeyError:
            r_id = "not found"
            r_list.append(r_id)
    recipient_ids.append(r_list)

# %%
df_2 = pd.DataFrame({"date": dates,
                   "from": sender_ids,
                     "to": recipient_ids,
                     "text": texts})

# %%
df_2
# Out:
#             date  from                                           to  \
# 0    14 May 2001     1                                          [0]
# 1     4 May 2001     1                                          [2]
# 2    18 Oct 2000     1                                          [3]
# 3    23 Oct 2000     1                                          [4]
# 4    31 Aug 2000     1                                          [5]
# 5    31 Aug 2000     1                                          [5]
# 6    22 Aug 2000     1                                       [6, 7]
# 7    14 Jul 2000     1                                          [8]
# 8    17 Oct 2000     1                                          [9]
# 9    16 Oct 2000     1                                         [10]
# 10   16 Oct 2000     1                       [not found, not found]
# 11   13 Oct 2000     1                                         [11]
# 12    9 Oct 2000     1                                         [12]
# 13    9 Oct 2000     1                                         [12]
# 14    5 Oct 2000     1                                         [13]
# 15    5 Oct 2000     1                                         [14]
# 16    4 Oct 2000     1                                         [15]
# 17    4 May 2001     1                                         [16]
# 18    3 Oct 2000     1                                         [17]
# 19    3 Oct 2000     1                                         [15]
# 20    3 Oct 2000     1                                         [18]
# 21    3 Oct 2000     1                                         [19]
# 22    2 Oct 2000     1                                         [20]
# 23   28 Sep 2000     1                                         [21]
# 24   28 Sep 2000     1                                         [22]
# 25   26 Sep 2000     1                                         [23]
# 26   26 Sep 2000     1                                         [17]
# 27   26 Sep 2000     1                                         [15]
# 28    3 May 2001     1                                         [24]
# 29   26 Sep 2000     1                                         [25]
# ..           ...   ...                                          ...
# 970  29 Mar 2001     1                                        [146]
# 971  29 Mar 2001     1                                        [146]
# 972  28 Mar 2001     1                                        [147]
# 973  28 Mar 2001     1                                        [129]
# 974  28 Mar 2001     1                                        [136]
# 975   7 Dec 2000   263                                     [1, 147]
# 976  28 Mar 2001     1                                        [143]
# 977  27 Mar 2001     1                                        [148]
# 978  27 Mar 2001     1                                        [149]
# 979  27 Mar 2001     1                                        [150]
# 980  26 Mar 2001     1                                        [121]
# 981  26 Mar 2001     1                                          [2]
# 982  26 Mar 2001     1                                        [129]
# 983  26 Mar 2001     1                                        [150]
# 984  26 Mar 2001     1                                        [151]
# 985  26 Mar 2001     1                                        [141]
# 986   7 Dec 2000     1                                 [42, 12, 43]
# 987  26 Mar 2001     1                                 [12, 42, 43]
# 988  26 Mar 2001     1                                        [152]
# 989  25 Mar 2001     1                                   [153, 143]
# 990  20 Mar 2001     1                                        [150]
# 991  19 Mar 2001     1                                        [143]
# 992  19 Mar 2001   264                                          [1]
# 993  19 Mar 2001   265  [127, 42, not found, 35, 1, 179, not found]
# 994  19 Mar 2001     1                                         [15]
# 995  19 Mar 2001     1                                        [143]
# 996  19 Mar 2001     1                                        [153]
# 997   6 Dec 2000     1                                         [17]
# 998  16 Mar 2001     1                                        [143]
# 999  15 Mar 2001     1                                        [154]
#
#                                                   text
# 0                          \nHere is our forecast\n\n
# 1    \nTraveling to have a business meeting takes t...
# 2                     \ntest successful.  way to go!!!
# 3    \nRandy,\n\n Can you send me a schedule of the...
# 4                \nLet's shoot for Tuesday at 11:45.
# 5    \nGreg,\n\n How about either next Tuesday or T...
# 6    \nPlease cc the following distribution list wi...
# 7                   \nany morning between 10 and 11:30
# 8    \n1. login:  pallen pw: ke9davis\n\n I don't t...
# 9    \n---------------------- Forwarded by Phillip ...
# 10   \nMr. Buckner,\n\n For delivered gas behind Sa...
# 11   \nLucy,\n\n Here are the rentrolls:\n\n\n\n Op...
# 12   \n---------------------- Forwarded by Phillip ...
# 13   \n---------------------- Forwarded by Phillip ...
# 14   \nDave, \n\n Here are the names of the west de...
# 15          \nPaula,\n\n 35 million is fine\n\nPhillip
# 16   \n---------------------- Forwarded by Phillip ...
# 17   \nTim,\n\nmike grigsby is having problems with...
# 18   \n---------------------- Forwarded by Phillip ...
# 19   \n---------------------- Forwarded by Phillip ...
# 20   \nBrenda,\n\nPlease use the second check as th...
# 21   \nI think Fletch has a good CPA.  I am still d...
# 22   \nBrenda,\n\n Please use the second check as m...
# 23   \n---------------------- Forwarded by Phillip ...
# 24   \nLiane,\n\n As we discussed yesterday, I am c...
# 25   \n---------------------- Forwarded by Phillip ...
# 26   \n---------------------- Forwarded by Phillip ...
# 27   \n---------------------- Forwarded by Phillip ...
# 28   \nReagan,\n\nJust wanted to give you an update...
# 29   \nNymex expiration is during this time frame. ...
# ..                                                 ...
# 970  \n---------------------- Forwarded by Phillip ...
# 971  \nCary,\n\nHere is the picture of the house I ...
# 972                                       \nno problem
# 973  \nReagan,\n\nThank you for the quick response ...
# 974  \nLarry,\n\nJacques has sent a document to Cla...
# 975  \nCan you please review the following systems ...
# 976  \nJacques,\n\nWould it be ok if I signed new c...
# 977  \n---------------------- Forwarded by Phillip ...
# 978  \n---------------------- Forwarded by Phillip ...
# 979  \nGreg,\n\nHere are my comments and questions ...
# 980  \nGrif,\n\nPlease provide a temporary id\n\nPh...
# 981  \nJohn,\n\nMike is fine with signing a new con...
# 982  \nReagan,\n\n Here is a photograhph of the hou...
# 983  \nGreg,\n\nSomething that I forgot to ask you....
# 984  \nkeith holst sent you an email with the details.
# 985  \nJacques,\n\nThe agreement looks fine.   My o...
# 986  \n---------------------- Forwarded by Phillip ...
# 987  \n---------------------- Forwarded by Phillip ...
# 988  \nSteve,\n\nTry bmckay@enron.com or Brad.McKay...
# 989  \nLarry,\n\nJacques has been working with Clau...
# 990  \nGreg,\n\njust a note to let you know I will ...
# 991  \nJacques,\n\nHere is Larry Lewter's response ...
# 992  \nPhillip,\n\nBarry had said that you were ask...
# 993  \nIn regards to your E-mail, I have recently b...
# 994  \nIna,\n\nCan you help me approve this request...
# 995  \nJacques,\n\nStill trying to close the loop o...
# 996  \nLarrry,\n\nI realize you are disappointed ab...
# 997  \n---------------------- Forwarded by Phillip ...
# 998  \nJacques,\n\nI think we reached an agreement ...
# 999  \n---------------------- Forwarded by Phillip ...
#
# [1000 rows x 4 columns]

# %% [markdown]
# **Задание 2 (15 баллов)**
#
# Сформируйте матрицу $A = (a_{ij})_{i,j = 1}^N$, где $a_{ij}$ - количество писем, которое индивид $i$ отправил индивиду $j$, $N$ - количество индивидуумов
#
# Далее из матрицы $A$ получим симметричную матрицу, которая будет показывать нам частоту коммуникаций между каждой парой индивидов: $A+A^T$. Постройте по данной матрице не направленный граф, где узлы должны называться по именам, которые вы извлекли из ```X-From``` и ```X-To```
#
# **Замечание.** Так как граф слишком большой, то вы можете оставить только наиболее активных участников.

# %% [markdown]
# **Задание 3 (25 баллов)**
#
# Оцените важность отдельных узлов, используя следующие меры:
#
# * Degree centrality
# * Closeness centrality
# * Betweenness centrality
# * Eigenvector centrality
#
# Подробнее читайте в статье: УЗЛЫ В СОЦИАЛЬНЫХ СЕТЯХ: МЕРЫ ЦЕНТРАЛЬНОСТИ И РОЛЬ В СЕТЕВЫХ ПРОЦЕССАХ
#
# Для каждой меры центральности выведите топ пользователей

# %% [markdown]
# **Бонусное задание (25 баллов)**
#
# Выделите темы, которые обсуждаются в письмах.
#
# Выберите одну из мер центральности и для топа пользователей по данной мере укажите, какие темы они обсуждают чаще всего и с кем.
